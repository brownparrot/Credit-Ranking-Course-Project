# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# ## load data

# %%
df_train = pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')
ID_test = df_test['ID']
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_12660\2718620448.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv('train.csv')

# %%
df_train.sample(5,random_state=42)
# Out:
#             ID Customer_ID     Month               Name   Age       Number  \
# 47044  0x1e799  CUS_0x5342    August  Alexei Oreskovicz    39  407-46-5571
# 44295  0x15e8f  CUS_0x3090  February           Severinf    24  884-45-8158
# 74783  0x11024   CUS_0xde4     March                NaN    29  733-85-7446
# 70975   0xe4f6  CUS_0x6831   January                B.z  2977  897-28-5647
# 46645  0x183f7  CUS_0xb46b  February        Marwa Awadb    34  686-19-5711
#
#           Profession Income_Annual  Base_Salary_PerMonth  Total_Bank_Accounts  \
# 47044  Media_Manager     142395.12          12049.260000                    7
# 44295         Doctor      43610.13           3640.177500                    2
# 74783      Architect      75402.52                   NaN                    2
# 70975       Engineer      28256.16                   NaN                    7
# 46645   Entrepreneur      17831.05           1382.920833                    6
#
# ...

# %%
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        80000 non-null  object
#  1   Customer_ID               80000 non-null  object
#  2   Month                     80000 non-null  object
#  3   Name                      71971 non-null  object
#  4   Age                       80000 non-null  object
#  5   Number                    80000 non-null  object
#  6   Profession                80000 non-null  object
#  7   Income_Annual             80000 non-null  object
#  8   Base_Salary_PerMonth      67968 non-null  float64
#  9   Total_Bank_Accounts       80000 non-null  int64
#  10  Total_Credit_Cards        80000 non-null  int64
#  11  Rate_Of_Interest          80000 non-null  int64
#  12  Total_Current_Loans       80000 non-null  object
# ...

# %%
print(df_train.describe())
# Out:
#        Base_Salary_PerMonth  Total_Bank_Accounts  Total_Credit_Cards  \
# count          67968.000000         80000.000000        80000.000000
# mean            4189.211406            17.046287           22.175438
# std             3181.371100           116.953761          128.083595
# min              303.645417            -1.000000            0.000000
# 25%             1623.664167             4.000000            4.000000
# 50%             3086.683333             6.000000            5.000000
# 75%             5950.863333             7.000000            7.000000
# max            15204.633333          1798.000000         1499.000000
#
#        Rate_Of_Interest  Delay_from_due_date  Total_Credit_Enquiries  \
# count      80000.000000         80000.000000            78451.000000
# mean          72.261350            21.081663               28.153115
# std          466.370837            14.855210              194.812201
# ...

# %%
# Number of non-null values
non_null_counts = df_train.notna().sum()

# Percentage of null values
null_percentage = df_train.isna().mean() * 100

# Combine the results into a DataFrame
na_info = pd.DataFrame({'Non-Null Count': non_null_counts, 'Percentage of Null Values': null_percentage})

print(na_info)
# Out:
#                           Non-Null Count  Percentage of Null Values
# ID                                 80000                    0.00000
# Customer_ID                        80000                    0.00000
# Month                              80000                    0.00000
# Name                               71971                   10.03625
# Age                                80000                    0.00000
# Number                             80000                    0.00000
# Profession                         80000                    0.00000
# Income_Annual                      80000                    0.00000
# Base_Salary_PerMonth               67968                   15.04000
# Total_Bank_Accounts                80000                    0.00000
# Total_Credit_Cards                 80000                    0.00000
# Rate_Of_Interest                   80000                    0.00000
# Total_Current_Loans                80000                    0.00000
# ...

# %%
issue_cols = ['Credit_Mix', 'Payment_of_Min_Amount', 'Profession', 'Payment_Behaviour']
for col in issue_cols:
    print(f'Unique values of {col}: {df_train[col].unique()}')
    print(f'Unique values of {col}: {df_test[col].unique()}')
# Out:
# Unique values of Credit_Mix: ['Standard' '_' 'Good' 'Bad']
# Unique values of Credit_Mix: ['Bad' '_' 'Good' 'Standard']
# Unique values of Payment_of_Min_Amount: ['No' 'NM' 'Yes']
# Unique values of Payment_of_Min_Amount: ['Yes' 'NM' 'No']
# Unique values of Profession: ['Musician' 'Writer' 'Doctor' 'Accountant' '_______' 'Engineer' 'Manager'
#  'Media_Manager' 'Teacher' 'Developer' 'Architect' 'Mechanic' 'Lawyer'
#  'Entrepreneur' 'Scientist' 'Journalist']
# Unique values of Profession: ['Mechanic' 'Developer' 'Entrepreneur' 'Architect' 'Teacher' 'Writer'
#  '_______' 'Journalist' 'Scientist' 'Doctor' 'Musician' 'Lawyer'
#  'Engineer' 'Accountant' 'Media_Manager' 'Manager']
# Unique values of Payment_Behaviour: ['Low_spent_Large_value_payments' 'Low_spent_Medium_value_payments'
#  'High_spent_Medium_value_payments' 'High_spent_Large_value_payments'
#  'Low_spent_Small_value_payments' 'High_spent_Small_value_payments'
#  '!@9#%8']
# ...

# %% [markdown]
# ## helper Functions

# %%
def count_strings(val):
    return 0 if pd.isna(val) else len(val.split(','))

# %%
def convert_to_months(val):
    if pd.isna(val):
        return 0
    else:
        years, months = int(val.split(" ")[0]), int (val.split(" ")[3])
    return years * 12 + months

# %%
def clean_and_convert_to_numeric(df, columns):
    """
    Cleans and converts specified columns to numeric.
    Non-numeric characters are removed, and the values are converted to numeric.
    """
    for col in columns:
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace(r'[^-.0-9]', '', regex=True)
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
def fill_missing_values(df, columns, group_by_col=None):
    """
    Fills missing values in specified columns. 
    Optionally, fills based on the median value grouped by a column.
    """
    for col in columns:
        if group_by_col:
            df[col] = df.groupby(group_by_col)[col].transform(lambda x: x.fillna(x.median()))
        df[col].fillna(df[col].median(), inplace=True)

# %%
def impute_with_group_mode(df, column, group_by_col, test_df=None):
    """
    Imputes missing values in a column based on the mode within a specified group.
    If no group mode exists, it uses the overall mode.
    Optionally applies the same logic to a test DataFrame.
    """
    # Calculate the overall mode
    overall_mode = df[column].mode()[0]

    # Impute missing values with group mode or overall mode in the primary DataFrame
    df[column] = df.groupby(group_by_col)[column].transform(
        lambda x: x.fillna(x.mode()[0] if not x.mode().empty else overall_mode)
    )
    df[column].fillna(overall_mode, inplace=True)

    # Optionally handle the test DataFrame
    if test_df is not None:
        test_df[column] = test_df.groupby(group_by_col)[column].transform(
            lambda x: x.fillna(x.mode()[0] if not x.mode().empty else overall_mode)
        )
        test_df[column].fillna(overall_mode, inplace=True)
        return df, test_df

    return df

# %%
def impute_categorical_columns_with_issues(df, issue_dict, group_by_col):
    """
    Imputes problematic values in categorical columns based on the mode within groups.
    If no group mode exists, it falls back to the overall mode.
    """
    for col, problem_value in issue_dict.items():
        if col in df.columns:
            # Calculate the overall mode, excluding problematic values
            overall_mode = df.loc[df[col] != problem_value, col].mode().get(0, 'Unknown')

            # Replace problematic values with group mode or overall mode
            df[col] = df.groupby(group_by_col)[col].transform(
                lambda x: x.replace(problem_value, x[x != problem_value].mode().get(0, overall_mode))
            )

            # Log results for verification (optional)
            print(f"Value counts for {col}:\n", df[col].value_counts())

    return df

# %% [markdown]
# ## Using helper functions

# %%
df_train['Loan_Count'] = df_train['Loan_Type'].apply(count_strings)
df_test['Loan_Count'] = df_test['Loan_Type'].apply(count_strings)

# %%
df_train['Credit_History_Age'] = df_train['Credit_History_Age'].apply(convert_to_months)
df_test['Credit_History_Age'] = df_test['Credit_History_Age'].apply(convert_to_months)

# %%
# Define the numeric columns
numeric_cols = [
    'Age', 'Income_Annual', 'Base_Salary_PerMonth', 'Total_Bank_Accounts', 'Total_Credit_Cards', 
    'Rate_Of_Interest', 'Total_Current_Loans', 'Delay_from_due_date', 'Total_Delayed_Payments', 
    'Credit_Limit', 'Total_Credit_Enquiries', 'Current_Debt_Outstanding', 'Ratio_Credit_Utilization', 
    'Per_Month_EMI', 'Monthly_Investment', 'Monthly_Balance', 'Loan_Count'
]

# Clean and convert to numeric
clean_and_convert_to_numeric(df_train, numeric_cols)
clean_and_convert_to_numeric(df_test, numeric_cols)


# Fill missing values, grouped by 'Customer_ID'
fill_missing_values(df_train, numeric_cols, group_by_col='Customer_ID')
fill_missing_values(df_test, numeric_cols, group_by_col='Customer_ID')
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_12660\1576555671.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\akash\AppData\Local\Temp\ipykernel_12660\1576555671.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
x1 = 'Credit_History_Age'
df_train, df_test = impute_with_group_mode(df_train, x1, 'Customer_ID', test_df=df_test)

# Print the number of NaNs left in the column
print(df_train[x1].isna().sum())
print(df_test[x1].isna().sum())
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_12660\1574031326.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(overall_mode, inplace=True)
# 0
# 0
# C:\Users\akash\AppData\Local\Temp\ipykernel_12660\1574031326.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Dictionary of categorical columns with issues
issue_categorical_dict = {
    "Credit_Mix": "_",
    "Payment_Behaviour": "!@9#%8",
    "Payment_of_Min_Amount": "NM",
    "Profession": "_______"}

# Impute categorical columns by Customer_ID group mode, falling back to overall mode
for col, problem_value in issue_categorical_dict.items():
    if col in df_train.columns:
        # Define the overall mode, excluding problematic values
        overall_mode = df_train.loc[df_train[col] != problem_value, col].mode().get(0, 'Unknown')

        # Replace the problematic value with group mode; fallback to overall mode if needed
        df_train[col] = df_train.groupby("Customer_ID")[col].transform(
            lambda x: x.replace(problem_value, x[x != problem_value].mode().get(0, overall_mode)))

        # Print value counts to check imputation results
        print(f"Value counts for {col}:\n", df_train[col].value_counts())
# Out:
# Value counts for Credit_Mix:
#  Credit_Mix
# Standard    36699
# Good        24275
# Bad         19026
# Name: count, dtype: int64
# Value counts for Payment_Behaviour:
#  Payment_Behaviour
# Low_spent_Small_value_payments      22144
# High_spent_Medium_value_payments    15452
# High_spent_Large_value_payments     12375
# Low_spent_Medium_value_payments     11724
# High_spent_Small_value_payments      9564
# Low_spent_Large_value_payments       8741
# Name: count, dtype: int64
# Value counts for Payment_of_Min_Amount:
#  Payment_of_Min_Amount
# Yes    47543
# No     32457
# Name: count, dtype: int64
# Value counts for Profession:
#  Profession
# Lawyer           5692
# Engineer         5497
# Mechanic         5493
# Architect        5479
# Scientist        5394
# Accountant       5389
# Media_Manager    5363
# Teacher          5344
# Developer        5343
# Journalist       5281
# Entrepreneur     5235
# Doctor           5214
# Manager          5172
# Musician         5065
# ...

# %%
issue_categorical_dict = {
    "Credit_Mix": "_",
    "Payment_Behaviour": "!@9#%8",
    "Payment_of_Min_Amount": "NM",
    "Profession": "_______"
}

df_train = impute_categorical_columns_with_issues(df_train, issue_categorical_dict, group_by_col="Customer_ID")
df_test = impute_categorical_columns_with_issues(df_test, issue_categorical_dict, group_by_col="Customer_ID")
# Out:
# Value counts for Credit_Mix:
#  Credit_Mix
# Standard    36699
# Good        24275
# Bad         19026
# Name: count, dtype: int64
# Value counts for Payment_Behaviour:
#  Payment_Behaviour
# Low_spent_Small_value_payments      22144
# High_spent_Medium_value_payments    15452
# High_spent_Large_value_payments     12375
# Low_spent_Medium_value_payments     11724
# High_spent_Small_value_payments      9564
# Low_spent_Large_value_payments       8741
# Name: count, dtype: int64
# Value counts for Payment_of_Min_Amount:
#  Payment_of_Min_Amount
# Yes    47543
# No     32457
# Name: count, dtype: int64
# Value counts for Profession:
#  Profession
# Lawyer           5692
# Engineer         5497
# Mechanic         5493
# Architect        5479
# Scientist        5394
# Accountant       5389
# Media_Manager    5363
# Teacher          5344
# Developer        5343
# Journalist       5281
# Entrepreneur     5235
# Doctor           5214
# Manager          5172
# Musician         5065
# ...

# %%
# Handle categorical variables if present
categorical_columns = ['Credit_Mix', 'Payment_Behaviour', 'Payment_of_Min_Amount', 'Month', 'Profession']
categorical_columns = [col for col in categorical_columns if col in df_train.columns]

# %%
for col in categorical_columns:
    df_train[col] = df_train.groupby('Customer_ID')[col].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else np.nan))
    df_train[col].fillna(df_train[col].mode()[0], inplace=True)
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_12660\1033574181.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train[col].fillna(df_train[col].mode()[0], inplace=True)
# C:\Users\akash\AppData\Local\Temp\ipykernel_12660\1033574181.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
categorical_columns = ['Credit_Mix', 'Payment_Behaviour', 'Payment_of_Min_Amount', 'Month', 'Profession']
categorical_columns = [col for col in categorical_columns if col in df_train.columns]
for col in categorical_columns:
    df_test[col] = df_test.groupby('Customer_ID')[col].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else np.nan))

# %% [markdown]
# ## Remove Outliers

# %%
def remove_outliers(df, columns, iqr_multiplier=1.5):
    """
    Removes outliers from the specified columns of a DataFrame based on the IQR method.
    
    """
    for col in columns:
        if df[col].dtype in ['int64', 'float64']:
            # Calculate Q1 (25th percentile) and Q3 (75th percentile)
            Q1 = df[col].quantile(0.01)
            Q3 = df[col].quantile(0.99)
            IQR = Q3 - Q1

            # Define outlier bounds
            lower_bound = Q1 - iqr_multiplier * IQR
            upper_bound = Q3 + iqr_multiplier * IQR

            # Filter out outliers
            df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    
    return df

# List of numeric columns
numeric_cols = [
    'Age', 'Income_Annual', 'Base_Salary_PerMonth', 'Total_Bank_Accounts', 
    'Total_Credit_Cards', 'Rate_Of_Interest', 'Total_Current_Loans', 
    'Delay_from_due_date', 'Total_Delayed_Payments', 'Credit_Limit', 
    'Total_Credit_Enquiries', 'Current_Debt_Outstanding', 
    'Ratio_Credit_Utilization', 'Per_Month_EMI', 'Monthly_Investment', 
    'Monthly_Balance', 'Loan_Count'
]

# Remove outliers from df_train
df_train = remove_outliers(df_train, numeric_cols)

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
# Apply label encoding to 'Profession' column

le = LabelEncoder()
df_train['Profession'] = le.fit_transform(df_train['Profession'])
df_test['Profession'] = le.transform(df_test['Profession'])

# Apply label encoding to other categorical columns
for col in categorical_columns:
    if col != 'Profession':  # Skip 'Profession' as it's already encoded
        df_train[col] = le.fit_transform(df_train[col])
        df_test[col] = le.transform(df_test[col])

# Drop unnecessary columns (IDs, names, or any unique identifiers)
columns_to_drop = ['ID', 'Name', 'Number', 'Loan_Type', 'Customer_ID']
df_train = df_train.drop(columns=[col for col in columns_to_drop if col in df_train.columns])
df_test = df_test.drop(columns=[col for col in columns_to_drop if col in df_test.columns])

# %%
credit_score_mapping = {'Poor': 0, 'Standard': 1, 'Good': 2}
df_train['Credit_Score'] = df_train['Credit_Score'].map(credit_score_mapping)

# %%
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77907 entries, 0 to 79999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     77907 non-null  int64
#  1   Age                       77907 non-null  int64
#  2   Profession                77907 non-null  int64
#  3   Income_Annual             77907 non-null  float64
#  4   Base_Salary_PerMonth      77907 non-null  float64
#  5   Total_Bank_Accounts       77907 non-null  int64
#  6   Total_Credit_Cards        77907 non-null  int64
#  7   Rate_Of_Interest          77907 non-null  int64
#  8   Total_Current_Loans       77907 non-null  int64
#  9   Delay_from_due_date       77907 non-null  int64
#  10  Total_Delayed_Payments    77907 non-null  float64
#  11  Credit_Limit              77907 non-null  float64
#  12  Total_Credit_Enquiries    77907 non-null  float64
#  13  Credit_Mix                77907 non-null  int64
# ...

# %%
df_test['ID'] = ID_test

# %%
df_train.to_csv('cleaned_train.csv', index=False)  
df_test.to_csv('cleaned_test.csv', index=False)
